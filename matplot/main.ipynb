# %% [markdown]
# # Basics of matplot |

# %%
import matplotlib.pyplot as plt

# %%
months = [1,2,3,4,5,6,7,8,]
sales = [1000, 100, 3000, 500, 1000, 0, 2200,4000]
plt.plot(months, sales , marker='o',linestyle="--",label="Sales",color="blue")
plt.title("Monthly Sales Data")
plt.xlabel("Months")
plt.ylabel("Sales")
plt.legend()
plt.grid()

# %% [markdown]
# # Bar chat

# %%
products = ['A', 'B', 'C', 'D', 'E']
sales = [1000, 2000, 3000, 4000, 5000]
plt.bar(products , sales, color='orange')
plt.title("Product Sales Data")
plt.xlabel("Products")
plt.ylabel("Sales")
plt.legend()
plt.grid(linestyle=':',linewidth=0.5)
plt.tight_layout()
plt.show()
# The code above creates two plots: a line plot for monthly sales data and a bar plot for product sales data.
# Out:
# /tmp/ipykernel_9848/913780585.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ## Pie chart

# %%
regions = ['North', 'South', 'East', 'West']
sales = [1000, 2000, 3000, 4000]
plt.pie(sales, labels=regions, autopct='%1.2f%%', startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title("Sales Distribution by Region")
plt.show()

# %% [markdown]
# ## histogram

# %%
scores = [90,91,92,93,94,95,100,50,20,30,40,50,60,70,80,90,10]
plt.hist(scores, bins=3, color='purple', edgecolor='black',)
plt.title("Score Distribution")
plt.xlabel("Scores")
plt.ylabel("Frequency")
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# # Scatter"

# %%
products = ['A', 'B', 'C', 'D', 'E']
sales = [1000, 2000, 3000, 4500, 500]
plt.scatter(products , sales, color='orange')
plt.title("Product Sales Data")
plt.xlabel("Products")
plt.ylabel("Sales")
plt.legend()
plt.grid(linestyle=':',linewidth=0.5)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_9848/1738150017.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.figure(figsize=(15,8))
plt.subplot(2,2,1)
plt.plot(products,sales)
plt.subplot(2,2,2)
plt.pie(sales,labels=products, autopct='%1.2f%%')
plt.subplot(2,2,3)
plt.scatter(products , sales, color='orange')
plt.subplot(2,2,4)
plt.bar(products,sales)
# Out:
# <BarContainer object of 5 artists>
